# %% [markdown]
# 1. What does an empty dictionary's code look like?
#
# dict = {}

# %%
dict = {}
dict
# Out:
# {}

# %% [markdown]
# 2. What is the value of a dictionary value with the key 'foo' and the value 42?
#
# its 42

# %%
dict = {'foo':42}
dict['foo']
# Out:
# 42

# %% [markdown]
# 3. What is the most significant distinction between a dictionary and a list?
#
# dictionary is represented with { } it has key value pairs
#
# list is represented with [ ] it dosent have key value pairs

# %% [markdown]
# 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?
#
# it returns a key error as 'foo' key dosent exsist

# %% [markdown]
# 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?
#
#
# spam = {'cat': 1, 'dog': 2}
#
# print('cat' in spam)
#
# checks if cat is key in spam dict and is simpler and faster
#
#
# spam = {'cat': 1, 'dog': 2}
#
# print('cat' in spam.keys()) used if we specifically wanna work with keys

# %% [markdown]
# 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?
#
# 'cat' in spam checks if 'cat' is a key in the dictionary.
# 'cat' in spam.values() checks if 'cat' is a value in the dictionary.

# %% [markdown]
# 7. What is a shortcut for the following code?
#
# if 'color' not in spam:
#
# spam['color'] = 'black'
#
# shortcut
#
#
#
# we can use setdefault
#
# spam.setdefault('color', 'black')

# %% [markdown]
# 8. How do you "pretty print" dictionary values using which module and function?
#
# using pprint
#
# import pprint
#
# spam = {'name': 'John', 'age': 30, 'city': 'New York'}
#
# pprint.pprint(spam)

# %%
import pprint

spam = {'name': 'John', 'age': 30, 'city': 'New York'}

pprint.pprint(spam)
# Out:
# {'age': 30, 'city': 'New York', 'name': 'John'}

# %% [markdown]
# 1. What is the role of the 'else' block in a try-except statement? Provide an example
# scenario where it would be useful.
#
#
# The else block in a try-except statement is used to define code that should be executed if no exceptions are raised in the try block. It is useful for running code that should only execute if the try block completes successfully without any errors
#
# this would be helpful while we are eeading a file and trying to process its content, like opening, reading, parsing, modifying etc

# %%
with open('data.txt', 'w') as file:
    file.write("Hello, this is a test file!\nThis is the second line.")

try:
    file = open('data.txt', 'r')
    content = file.read()
except FileNotFoundError:
    print("The file was not found.")
else:
    print("File read successfully. Proceeding with processing...")
finally:
    file.close()
# Out:
# File read successfully. Proceeding with processing...

# %% [markdown]
# 2. Can a try-except block be nested inside another try-except block? Explain with an
# example.

# %%
try:
    x = 10 / 0
except ZeroDivisionError:
    print("Caught a ZeroDivisionError")
    try:
        y = 10 / 2
        print("No exception in inner try block:", y)
    except ZeroDivisionError:
        print("Caught a ZeroDivisionError in inner try block")
# Out:
# Caught a ZeroDivisionError
# No exception in inner try block: 5.0

# %% [markdown]
# 3. How can you create a custom exception class in Python? Provide an example that
# demonstrates its usage.

# %%
class InvalidAgeError(Exception):
    def __init__(self, message="Age is not valid"):
        self.message = message
        super().__init__(self.message)
def check_age(age):
    if age < 0:
        raise InvalidAgeError("Age cannot be negative")
    else:
        print(f"Age is valid: {age}")


try:
    check_age(-5)
except InvalidAgeError as e:
    print(e)
# Out:
# Age cannot be negative

# %% [markdown]
# 4. What are some common exceptions that are built-in to Python?
#
# IndexError: Raised when a sequence index is out of range.
#
# KeyError: Raised when a dictionary key is not found.
#
# ValueError: Raised when a function receives an argument of the correct type but an inappropriate value.
#
# TypeError: Raised when an operation or function is applied to an object of inappropriate type.
#
# FileNotFoundError: Raised when a file or directory is requested but cannot be found.
#
# ZeroDivisionError: Raised when division by zero is attempted.
#
# .
#
# 5. What is logging in Python, and why is it important in software development?
#
# It helps in debugging by recording what happened in the program.
#
# It provides insights into the program's behavior over time.
#
# also helps in troubleshooting production issues without needing to reproduce them.
#
# .
# 6. Explain the purpose of log levels in Python logging and provide examples of when
# each log level would be appropriate.
#
# DEBUG: Provides Detailed information, typically useful only for diagnosing problems. Example: Debugging a function’s output.
#
# INFO: Provides General information about program execution. Example: Informing the user about successful actions like file processing.
#
# WARNING: Indicates a potential problem or something unexpected if it happens, but the program continues. Example: Using deprecated features.
#
# ERROR: An error occurred, but the program can still continue. Example: A failed database connection.
#
# CRITICAL: A very serious error that may lead to program's termination. Example: System crash or failure of a critical service.

# %% [markdown]
# 7. What are log formatters in Python logging, and how can you customise the log
# message format using formatters?

# %%
import logging

logger = logging.getLogger()
handler = logging.StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)
logger.setLevel(logging.DEBUG)

logger.info("This is an info message")
# Out:
# INFO:root:This is an info message
# This is an info message
# 2024-12-06 19:55:29,562 - root - INFO - This is an info message

# %% [markdown]
# 8. How can you set up logging to capture log messages from multiple modules or
# classes in a Python application?
#
#
# To capture log messages from multiple modules, you can configure logging in a centralized location, typically in the main entry script. You can use logging.basicConfig() to set up a common configuration, then use logger.getLogger() in different modules
#
# .
#
# 9. What is the difference between the logging and print statements in Python? When
# should you use logging over print statements in a real-world application?
#
# Logging provides different log levels, persistent logs, timestamps, and can be directed to files or external systems. It is used for debugging, tracking, and monitoring the application over time.
#
#
# Print statements are used to output data to the console and are not suitable for production as they are not organized or stored.

# %% [markdown]
# 10. Write a Python program that logs a message to a file named "app.log" with the
# following requirements:
# ● The log message should be "Hello, World!"
# ● The log level should be set to "INFO."
# ● The log file should append new log entries without overwriting previous ones.

# %%
import logging

logging.basicConfig(filename='app.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

logging.info("Hello, World!")
# Out:
# INFO:root:Hello, World!
# Hello, World!
# 2024-12-06 20:03:32,702 - root - INFO - Hello, World!

# %% [markdown]
# 11. Create a Python program that logs an error message to the console and a file named
# "errors.log" if an exception occurs during the program's execution. The error
# message should include the exception type and a timestamp

# %%
import logging

logger = logging.getLogger()
file_handler = logging.FileHandler('errors.log')
console_handler = logging.StreamHandler()

formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)

logger.addHandler(file_handler)
logger.addHandler(console_handler)
logger.setLevel(logging.ERROR)

try:
    x = 10 / 0
except ZeroDivisionError as e:
    logger.error(f"Error occurred: {e}")
# Out:
# ERROR:root:Error occurred: division by zero
# Error occurred: division by zero
# 2024-12-06 20:05:19,249 - root - ERROR - Error occurred: division by zero
# 2024-12-06 20:05:19,249 - ERROR - Error occurred: division by zero
